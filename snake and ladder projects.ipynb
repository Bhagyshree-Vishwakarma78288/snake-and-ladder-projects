# %% [markdown]
# ![board-game-snake-ladder_1308-5206.avif](attachment:board-game-snake-ladder_1308-5206.avif)

# %%
oops looping conditional satatment functions

# %%
ideas
number of players - shree , rukhsar, neelam, shweta
dice - 1,2,3,4,5,6
random
score = 36 user will win
snakes{mouth:tail}
ladder = {tip:height}

# %%
import random

# %%
random.randint(1,6)
# Out:
# 5

# %%
if else
4 snake 3 ladder

# %%
snake = [11,25]
if score in [11,21]:

# %%
# oops consept

# %%
class game():
    def __init__(self,player_name):
        self.player_name = player_name
        self.score = 0 
        self.game_over = False
        
    def move(self):
        if self.game_over:
            
            ladders = {6:16,12:19,15:27}
            snakes = {8:3,23:16,25:20,35:28}
        
            dice = random.randint(1,6)
        if self.score + dice > 36:
        
        else:
                self.score += dice
            if self.score in snakes:
                self.score = snakes[self.score]
            if self.score in ladders:
                self.score = snakes[self.score]
            if dice ==6:
                dice = random.randint(1,6)
                self.score += dice
            if self.score in snakes:
                self.score = snakes[self.score]
            if self.score in ladders:
                self.score = snakes[self.score]
# Out:
#   File <tokenize>:18
#     if self.score in snakes:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
class game():
    moves = []
    rank = 1
    def __init__(self,player_name):
        self.player_name = player_name
        self.score = 0 
        self.game_over = False
        self.rank=0 
        
    def move(self):
        if self.game_over:
            print(f"{self.player_name} has already won the game. he is at{self.rank}")
            return 
            
        ladders = {6:16,12:19,15:27}
        snakes = {8:3,23:16,25:20,35:28}
        
        dice = random.randint(1,6)
        
        if self.score + dice > 36:
            game.moves.append(f"{self.player_name} score is at{self.score}. he got {dice}. he needs ecxactally{36-self.score}")
            print(f"{self.player_name} score is at{self.score}. he got {dice}. he needs ecxactally{36-self.score}")
            return 
    
        else:
            self.score += dice
            print(f"{self.player_name} has got{dice} his got {dice} his new score is {self.score}")
            game.moves.append(f"{self.player_name} has got{dice} his got {dice} his new score is {self.score}")
                 
            if self.score in snakes:
                self.score = snakes[self.score]
                print(f"{self.player_name} was bit by snake he pushed back to {self.score}")
                game.moves.append(f"{self.player_name} was bit by snake he pushed back to {self.score}")
            if self.score in ladders:
                self.score = ladders[self.score]
                print(f"{self.player_name} was bit by ladder he reched  to {self.score}")
                game.moves.append(f"{self.player_name} was bit by ladder he reched  to {self.score}")
            
            if self.score ==36:
               
                print(self.player_name,"wins")
                self.rank =game.rank
                game.moves.append(f"{self.player_name}wins. he is number{self.rank}")
                game.rank += 1 
                self.game_over = True

# %%
shree = game("shree")
rukhsar = game("rukhsar")
neelam  = game("neelam")
shubra = game("shubra")

# %%
shree.move() , rukhsar.move(), neelam.move() ,shubra.move()
# Out:
# shree has already won the game. he is at1
# rukhsar has got4 his got 4 his new score is 34
# neelam score is at34. he got 5. he needs ecxactally2
# shubra has got1 his got 1 his new score is 35
# shubra was bit by snake he pushed back to 28
# (None, None, None, None)

# %%
shree.score
# Out:
# 36
